# %% [markdown]
# # Table Basics

# %% [markdown]
# 31.10.2025 Sanna Määttä

# %% [markdown]
# ### Introduction
# - This Notebook contains examples and tasks how to use Pandas to create tables.

# %%
# Take libraries in use
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read data to DataFrame

# %%
df = sns.load_dataset('taxis')
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
# std       1.203768     3.827867    11.551804     2.44856     1.415267
#
#              total
# count  6433.000000
# mean     18.517794
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      13.815570

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
# remove rows with null values
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6341 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 743.1+ KB

# %% [markdown]
# ### Create tables using data

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %% [markdown]
# ## Cross-tabulation with Pandas
# - https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html

# %%
# Default
# pandas.crosstab(index, columns, values=None, rownames=None, colnames=None,
#                aggfunc=None, margins=False, margins_name='All',
#                dropna=True, normalize=False)

# %%
# Cross-tabulatin table with orginal variable names
pd.crosstab(df['pickup_borough'],df['payment'],
            margins=True, margins_name="Total")
# Out:
# payment         cash  credit card  Total
# pickup_borough
# Bronx             25           74     99
# Brooklyn         118          260    378
# Manhattan       1394         3832   5226
# Queens           258          380    638
# Total           1795         4546   6341

# %%
# Change the names of row and column titles
pd.crosstab(df['pickup_borough'],df['payment'],
            rownames =['Pickup place'], colnames = ['Payment method'],
            margins=True, margins_name="Total")
# Out:
# Payment method  cash  credit card  Total
# Pickup place
# Bronx             25           74     99
# Brooklyn         118          260    378
# Manhattan       1394         3832   5226
# Queens           258          380    638
# Total           1795         4546   6341

# %%
# Show values as fractions
# normalize based on 'index', when total per row = 1.0
# option is to normalize per 'columns'
pd.crosstab(df['pickup_borough'],df['payment'],
            rownames =['Pickup place'], colnames = ['Payment method'],
            normalize = 'index',
            margins=True, margins_name="Total")
# Out:
# Payment method      cash  credit card
# Pickup place
# Bronx           0.252525     0.747475
# Brooklyn        0.312169     0.687831
# Manhattan       0.266743     0.733257
# Queens          0.404389     0.595611
# Total           0.283078     0.716922

# %%
# Show values as % by multiplying result with 100
pd.crosstab(df['pickup_borough'],df['payment'],
            rownames =['Pickup place'], colnames = ['Payment method'],
            normalize = 'index',
            margins=True, margins_name="Total")*100
# Out:
# Payment method       cash  credit card
# Pickup place
# Bronx           25.252525    74.747475
# Brooklyn        31.216931    68.783069
# Manhattan       26.674321    73.325679
# Queens          40.438871    59.561129
# Total           28.307838    71.692162

# %%
# check variable names
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
# Use more variables in cross-tabulation
pd.crosstab([df['pickup_borough'], df['payment']],df['dropoff_borough'],
            rownames=['Pickup place', 'Payment method'], colnames=['Dropoff place'],
            margins=True, margins_name="Total")
# Out:
# Dropoff place                Bronx  Brooklyn  Manhattan  Queens  \
# Pickup place Payment method
# Bronx        cash               21         0          4       0
#              credit card        45         4         21       4
# Brooklyn     cash                0       104         11       3
#              credit card         5       176         56      23
# Manhattan    cash               27        35       1298      34
#              credit card        27       116       3559     128
# Queens       cash                4        14         47     193
#              credit card         7        48        176     149
# Total                          136       497       5172     534
#
# Dropoff place                Staten Island  Total
# Pickup place Payment method
# Bronx        cash                        0     25
#              credit card                 0     74
# Brooklyn     cash                        0    118
#              credit card                 0    260
# Manhattan    cash                        0   1394
#              credit card                 2   3832
# Queens       cash                        0    258
#              credit card                 0    380
# Total                                    2   6341

# %% [markdown]
# ## Pivot table

# %% [markdown]
# ### Cross-tabulation using Pivot table
# https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %%
# default
# pandas.pivot_table(data, values=None, index=None, columns=None,
#                   aggfunc='mean', fill_value=None, margins=False,
#                   dropna=True, margins_name='All', observed=<no_default>, sort=True)

# %%
# Show pivot table for variables with default (i.e. aggfunc = 'mean')
# Parameter "values" define
pd.pivot_table(df, values='passengers',
               index=['pickup_borough'])
# Out:
#                 passengers
# pickup_borough
# Bronx             1.191919
# Brooklyn          1.314815
# Manhattan         1.569269
# Queens            1.528213

# %%
# use aggfunc "sum" to get frequency
pd.pivot_table(df, values='passengers',
               index=['pickup_borough'],
               aggfunc="sum")
# Out:
#                 passengers
# pickup_borough
# Bronx                  118
# Brooklyn               497
# Manhattan             8201
# Queens                 975

# %%
#  One variable in row and another in column
pd.pivot_table(df, values='passengers',
               index=['pickup_borough'],
               columns=['dropoff_borough'],
               aggfunc="sum")
# Out:
# dropoff_borough  Bronx  Brooklyn  Manhattan  Queens  Staten Island
# pickup_borough
# Bronx             84.0       4.0       26.0     4.0            NaN
# Brooklyn           7.0     354.0      101.0    35.0            NaN
# Manhattan         70.0     223.0     7634.0   272.0            2.0
# Queens            15.0     106.0      348.0   506.0            NaN

# %%
# fill NaN values with 0
#  One variable in row and another in column
pd.pivot_table(df, values='passengers',
               index=['pickup_borough'],
               columns=['dropoff_borough'],
               fill_value = 0,
               aggfunc="sum")
# Out:
# dropoff_borough  Bronx  Brooklyn  Manhattan  Queens  Staten Island
# pickup_borough
# Bronx               84         4         26       4              0
# Brooklyn             7       354        101      35              0
# Manhattan           70       223       7634     272              2
# Queens              15       106        348     506              0

# %%
# present several aggfunctions is result
df.pivot_table(values='passengers', index=['pickup_borough', 'dropoff_borough'],
                   aggfunc=['min', 'median', 'max'])
# Out:
#                                       min     median        max
#                                passengers passengers passengers
# pickup_borough dropoff_borough
# Bronx          Bronx                    1        1.0          5
#                Brooklyn                 1        1.0          1
#                Manhattan                0        1.0          2
#                Queens                   1        1.0          1
# Brooklyn       Bronx                    1        1.0          3
#                Brooklyn                 0        1.0          6
#                Manhattan                1        1.0          6
#                Queens                   1        1.0          6
# Manhattan      Bronx                    1        1.0          5
#                Brooklyn                 0        1.0          6
#                Manhattan                0        1.0          6
#                Queens                   0        1.0          6
#                Staten Island            1        1.0          1
# Queens         Bronx                    1        1.0          5
#                Brooklyn                 0        1.0          6
#                Manhattan                0        1.0          6
#                Queens                   0        1.0          6

# %%
# use same precision for all data (no decimals)
# use .style.format(precision=0)
df.pivot_table(values='passengers', index=['pickup_borough', 'dropoff_borough'],
                   aggfunc=['min', 'median', 'max']).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbb22">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbb22_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_dbb22_level0_col1" class="col_heading level0 col1" >median</th>
#       <th id="T_dbb22_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_dbb22_level1_col0" class="col_heading level1 col0" >passengers</th>
#       <th id="T_dbb22_level1_col1" class="col_heading level1 col1" >passengers</th>
#       <th id="T_dbb22_level1_col2" class="col_heading level1 col2" >passengers</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pickup_borough</th>
#       <th class="index_name level1" >dropoff_borough</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbb22_level0_row0" class="row_heading level0 row0" rowspan="4">Bronx</th>
#       <th id="T_dbb22_level1_row0" class="row_heading level1 row0" >Bronx</th>
#       <td id="T_dbb22_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_dbb22_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_dbb22_row0_col2" class="data row0 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row1" class="row_heading level1 row1" >Brooklyn</th>
#       <td id="T_dbb22_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_dbb22_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_dbb22_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row2" class="row_heading level1 row2" >Manhattan</th>
#       <td id="T_dbb22_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_dbb22_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_dbb22_row2_col2" class="data row2 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row3" class="row_heading level1 row3" >Queens</th>
#       <td id="T_dbb22_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_dbb22_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_dbb22_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level0_row4" class="row_heading level0 row4" rowspan="4">Brooklyn</th>
#       <th id="T_dbb22_level1_row4" class="row_heading level1 row4" >Bronx</th>
#       <td id="T_dbb22_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_dbb22_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_dbb22_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row5" class="row_heading level1 row5" >Brooklyn</th>
#       <td id="T_dbb22_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_dbb22_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_dbb22_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row6" class="row_heading level1 row6" >Manhattan</th>
#       <td id="T_dbb22_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_dbb22_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_dbb22_row6_col2" class="data row6 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row7" class="row_heading level1 row7" >Queens</th>
#       <td id="T_dbb22_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_dbb22_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_dbb22_row7_col2" class="data row7 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level0_row8" class="row_heading level0 row8" rowspan="5">Manhattan</th>
#       <th id="T_dbb22_level1_row8" class="row_heading level1 row8" >Bronx</th>
#       <td id="T_dbb22_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_dbb22_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_dbb22_row8_col2" class="data row8 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row9" class="row_heading level1 row9" >Brooklyn</th>
#       <td id="T_dbb22_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_dbb22_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_dbb22_row9_col2" class="data row9 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row10" class="row_heading level1 row10" >Manhattan</th>
#       <td id="T_dbb22_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_dbb22_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_dbb22_row10_col2" class="data row10 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row11" class="row_heading level1 row11" >Queens</th>
#       <td id="T_dbb22_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_dbb22_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_dbb22_row11_col2" class="data row11 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row12" class="row_heading level1 row12" >Staten Island</th>
#       <td id="T_dbb22_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_dbb22_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_dbb22_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level0_row13" class="row_heading level0 row13" rowspan="4">Queens</th>
#       <th id="T_dbb22_level1_row13" class="row_heading level1 row13" >Bronx</th>
#       <td id="T_dbb22_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_dbb22_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_dbb22_row13_col2" class="data row13 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row14" class="row_heading level1 row14" >Brooklyn</th>
#       <td id="T_dbb22_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_dbb22_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_dbb22_row14_col2" class="data row14 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row15" class="row_heading level1 row15" >Manhattan</th>
#       <td id="T_dbb22_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_dbb22_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_dbb22_row15_col2" class="data row15 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbb22_level1_row16" class="row_heading level1 row16" >Queens</th>
#       <td id="T_dbb22_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_dbb22_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_dbb22_row16_col2" class="data row16 col2" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highlight maximum and minimum values
df.pivot_table(values='passengers', index=['pickup_borough', 'dropoff_borough'],
                   aggfunc=['min', 'median', 'max']).style.format(precision=0)\
                    .highlight_max(color='lightgreen', axis=0)\
                    .highlight_min(color='yellow', axis=0)
# Out:
# <style type="text/css">
# #T_63108_row0_col0, #T_63108_row1_col0, #T_63108_row3_col0, #T_63108_row4_col0, #T_63108_row5_col2, #T_63108_row6_col0, #T_63108_row6_col2, #T_63108_row7_col0, #T_63108_row7_col2, #T_63108_row8_col0, #T_63108_row9_col2, #T_63108_row10_col2, #T_63108_row11_col2, #T_63108_row12_col0, #T_63108_row13_col0, #T_63108_row14_col2, #T_63108_row15_col2, #T_63108_row16_col2 {
#   background-color: lightgreen;
# }
# #T_63108_row0_col1, #T_63108_row1_col1, #T_63108_row2_col1, #T_63108_row3_col1, #T_63108_row4_col1, #T_63108_row5_col1, #T_63108_row6_col1, #T_63108_row7_col1, #T_63108_row8_col1, #T_63108_row9_col1, #T_63108_row10_col1, #T_63108_row11_col1, #T_63108_row12_col1, #T_63108_row13_col1, #T_63108_row14_col1, #T_63108_row15_col1, #T_63108_row16_col1 {
#   background-color: lightgreen;
#   background-color: yellow;
# }
# #T_63108_row1_col2, #T_63108_row2_col0, #T_63108_row3_col2, #T_63108_row5_col0, #T_63108_row9_col0, #T_63108_row10_col0, #T_63108_row11_col0, #T_63108_row12_col2, #T_63108_row14_col0, #T_63108_row15_col0, #T_63108_row16_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_63108">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63108_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_63108_level0_col1" class="col_heading level0 col1" >median</th>
#       <th id="T_63108_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_63108_level1_col0" class="col_heading level1 col0" >passengers</th>
#       <th id="T_63108_level1_col1" class="col_heading level1 col1" >passengers</th>
#       <th id="T_63108_level1_col2" class="col_heading level1 col2" >passengers</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pickup_borough</th>
#       <th class="index_name level1" >dropoff_borough</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63108_level0_row0" class="row_heading level0 row0" rowspan="4">Bronx</th>
#       <th id="T_63108_level1_row0" class="row_heading level1 row0" >Bronx</th>
#       <td id="T_63108_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_63108_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_63108_row0_col2" class="data row0 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row1" class="row_heading level1 row1" >Brooklyn</th>
#       <td id="T_63108_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_63108_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_63108_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row2" class="row_heading level1 row2" >Manhattan</th>
#       <td id="T_63108_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_63108_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_63108_row2_col2" class="data row2 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row3" class="row_heading level1 row3" >Queens</th>
#       <td id="T_63108_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_63108_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_63108_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level0_row4" class="row_heading level0 row4" rowspan="4">Brooklyn</th>
#       <th id="T_63108_level1_row4" class="row_heading level1 row4" >Bronx</th>
#       <td id="T_63108_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_63108_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_63108_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row5" class="row_heading level1 row5" >Brooklyn</th>
#       <td id="T_63108_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_63108_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_63108_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row6" class="row_heading level1 row6" >Manhattan</th>
#       <td id="T_63108_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_63108_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_63108_row6_col2" class="data row6 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row7" class="row_heading level1 row7" >Queens</th>
#       <td id="T_63108_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_63108_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_63108_row7_col2" class="data row7 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level0_row8" class="row_heading level0 row8" rowspan="5">Manhattan</th>
#       <th id="T_63108_level1_row8" class="row_heading level1 row8" >Bronx</th>
#       <td id="T_63108_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_63108_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_63108_row8_col2" class="data row8 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row9" class="row_heading level1 row9" >Brooklyn</th>
#       <td id="T_63108_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_63108_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_63108_row9_col2" class="data row9 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row10" class="row_heading level1 row10" >Manhattan</th>
#       <td id="T_63108_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_63108_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_63108_row10_col2" class="data row10 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row11" class="row_heading level1 row11" >Queens</th>
#       <td id="T_63108_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_63108_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_63108_row11_col2" class="data row11 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row12" class="row_heading level1 row12" >Staten Island</th>
#       <td id="T_63108_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_63108_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_63108_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level0_row13" class="row_heading level0 row13" rowspan="4">Queens</th>
#       <th id="T_63108_level1_row13" class="row_heading level1 row13" >Bronx</th>
#       <td id="T_63108_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_63108_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_63108_row13_col2" class="data row13 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row14" class="row_heading level1 row14" >Brooklyn</th>
#       <td id="T_63108_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_63108_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_63108_row14_col2" class="data row14 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row15" class="row_heading level1 row15" >Manhattan</th>
#       <td id="T_63108_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_63108_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_63108_row15_col2" class="data row15 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63108_level1_row16" class="row_heading level1 row16" >Queens</th>
#       <td id="T_63108_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_63108_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_63108_row16_col2" class="data row16 col2" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Frequency and Percentage distributions in table
# - use crosstab() to calculate values
# - https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html

# %%
# Create DataFrame to include the data
pd.crosstab(df['pickup_borough'], 'Freq')
# Out:
# col_0           Freq
# pickup_borough
# Bronx             99
# Brooklyn         378
# Manhattan       5226
# Queens           638

# %%
# Modify row and column names
pd.crosstab(df['pickup_borough'], 'Freq',
            rownames =['Pickup place'], colnames = [''])
# Out:
#               Freq
# Pickup place
# Bronx           99
# Brooklyn       378
# Manhattan     5226
# Queens         638

# %% [markdown]
# ## Data formatting
# - https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.format.html

# %%
# Store the result in new DataFrame for formatting
df1 = pd.crosstab(df['pickup_borough'], 'Freq',
            rownames =['Pickup place'], colnames = [''])
df1
# Out:
#               Freq
# Pickup place
# Bronx           99
# Brooklyn       378
# Manhattan     5226
# Queens         638

# %%
# count sum and values for percentages
n = df1['Freq'].sum() # count total sum
df1['%'] = df1['Freq']/n*100 # Count % value and add new column
df1
# Out:
#               Freq          %
# Pickup place
# Bronx           99   1.561268
# Brooklyn       378   5.961205
# Manhattan     5226  82.416023
# Queens         638  10.061504

# %%
# Create format for data
format = {'1km':'{:.0f}', '%':'{:.1f} %'}
# present table using the format
df1.style.format(format)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4334e">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_4334e_level0_col0" class="col_heading level0 col0" >Freq</th>
#       <th id="T_4334e_level0_col1" class="col_heading level0 col1" >%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pickup place</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4334e_level0_row0" class="row_heading level0 row0" >Bronx</th>
#       <td id="T_4334e_row0_col0" class="data row0 col0" >99</td>
#       <td id="T_4334e_row0_col1" class="data row0 col1" >1.6 %</td>
#     </tr>
#     <tr>
#       <th id="T_4334e_level0_row1" class="row_heading level0 row1" >Brooklyn</th>
#       <td id="T_4334e_row1_col0" class="data row1 col0" >378</td>
#       <td id="T_4334e_row1_col1" class="data row1 col1" >6.0 %</td>
#     </tr>
#     <tr>
#       <th id="T_4334e_level0_row2" class="row_heading level0 row2" >Manhattan</th>
#       <td id="T_4334e_row2_col0" class="data row2 col0" >5226</td>
#       <td id="T_4334e_row2_col1" class="data row2 col1" >82.4 %</td>
#     </tr>
#     <tr>
#       <th id="T_4334e_level0_row3" class="row_heading level0 row3" >Queens</th>
#       <td id="T_4334e_row3_col0" class="data row3 col0" >638</td>
#       <td id="T_4334e_row3_col1" class="data row3 col1" >10.1 %</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Tasks

# %% [markdown]
# Load data of 'penguins' using Seaborn.
# Then make 3 different tables using data where
# - table contains frequencies and % of one variable
# - table contains cross-tabulation for two variables using crosstab
# - table contain cross-tabulation for two variables using pivot_table
# Pay attention, which would be good variables to select (categorical or numerical, missing values vs. no missing values, etc.)

# %%
df = sns.load_dataset('penguins')
df.head(20)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 3           NaN     NaN
# 4        3450.0  Female
# 5        3650.0    Male
# 6        3625.0  Female
# 7        4675.0    Male
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  Female
# 13       3800.0    Male
# 14       4400.0    Male
# 15       3700.0  Female
# 16       3450.0  Female
# 17       4500.0    Male
# 18       3325.0  Female
# 19       4200.0    Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
df2 = pd.crosstab(df['species'], 'Freq',
            rownames =['Type of Species'], colnames = [''])
df2

m = df2['Freq'].sum() 
df2['%'] = df2['Freq']/m*100
df2

format = {'1km':'{:.0f}', '%':'{:.1f} %'}

df2.style.format(format)
# Out:
# <style type="text/css">
# </style>
# <table id="T_41cbe">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_41cbe_level0_col0" class="col_heading level0 col0" >Freq</th>
#       <th id="T_41cbe_level0_col1" class="col_heading level0 col1" >%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Type of Species</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41cbe_level0_row0" class="row_heading level0 row0" >Adelie</th>
#       <td id="T_41cbe_row0_col0" class="data row0 col0" >146</td>
#       <td id="T_41cbe_row0_col1" class="data row0 col1" >43.8 %</td>
#     </tr>
#     <tr>
#       <th id="T_41cbe_level0_row1" class="row_heading level0 row1" >Chinstrap</th>
#       <td id="T_41cbe_row1_col0" class="data row1 col0" >68</td>
#       <td id="T_41cbe_row1_col1" class="data row1 col1" >20.4 %</td>
#     </tr>
#     <tr>
#       <th id="T_41cbe_level0_row2" class="row_heading level0 row2" >Gentoo</th>
#       <td id="T_41cbe_row2_col0" class="data row2 col0" >119</td>
#       <td id="T_41cbe_row2_col1" class="data row2 col1" >35.7 %</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(df['species'], df['island'],
            rownames=['Types of Species'], colnames=['Per Island'],
            margins=True, margins_name="Total")
# Out:
# Per Island        Biscoe  Dream  Torgersen  Total
# Types of Species
# Adelie                44     55         47    146
# Chinstrap              0     68          0     68
# Gentoo               119      0          0    119
# Total                163    123         47    333

# %%
df.pivot_table(values='body_mass_g', index=['species', 'island'],
               aggfunc=['min', 'median', 'max'])
# Out:
#                             min      median         max
#                     body_mass_g body_mass_g body_mass_g
# species   island
# Adelie    Biscoe         2850.0      3750.0      4775.0
#           Dream          2900.0      3600.0      4650.0
#           Torgersen      2900.0      3700.0      4700.0
# Chinstrap Dream          2700.0      3700.0      4800.0
# Gentoo    Biscoe         3950.0      5050.0      6300.0
