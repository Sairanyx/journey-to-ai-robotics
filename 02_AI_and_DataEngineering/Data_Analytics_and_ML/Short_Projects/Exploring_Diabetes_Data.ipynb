# %% [markdown]
# # Classwork Assignment: Exploring Diabetes Data
# ## Dataset: PIMA Indians Diabetes Dataset
#
# ## Objective:
# In this classwork, you will explore a real-world dataset related to diabetes diagnosis. You will:
# - Understand the dataset structure
# - Visualize key patterns and distributions
# - Extract meaningful insights
#
# ## Dataset Description
# The PIMA Indians Diabetes Dataset contains medical data for women aged 21+ from a specific population. The goal is to analyze features related to diabetes risk factors.
#
# ### Key Features:
# - Pregnancies – Number of times pregnant
# - Glucose – Blood glucose level
# - BloodPressure – Blood pressure (mm Hg)
# - SkinThickness – Skin fold thickness (mm)
# - Insulin – Insulin level (mu U/ml)
# - BMI – Body Mass Index
# - DiabetesPedigreeFunction – Genetic risk score
# - Age – Patient’s age
# - Outcome – (Target) 1 = Diabetes, 0 = No Diabetes
#
# ## Instructions
# Follow these steps to complete your assignment.
#
# ## Cheat Sheets
# Learn to use the cheat sheets in coding:
# [Pandas cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# [Numpy cheat sheet](media.datacamp.com/legacy/image/upload/v1676302459/Marketing/Blog/Numpy_Cheat_Sheet.pdf)
# [Matplotlib cheat sheet](https://matplotlib.org/cheatsheets/cheatsheets.pdf)
# [Seaborn cheat sheet](https://media.datacamp.com/legacy/image/upload/v1676302629/Marketing/Blog/Seaborn_Cheat_Sheet.pdf)
#
#
# ### Step 1: Load the Dataset
# Tasks:
# 1. Import necessary libraries (`pandas`, `matplotlib`, `seaborn`).
# 2. Define meaningful column names: `columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]`.
# 3. Load the dataset from [here](https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv) into a Pandas DataFrame (hint: read_csv()).
# 4. Display the first 5 rows to understand its structure.
#
#
# **Note:** When we load the PIMA Indians Diabetes Dataset from a raw CSV file (like from a URL), it does not include column headers. The dataset consists of numbers without labels, which makes it difficult to understand and analyze.

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

# %%
df = pd.read_csv(url, header=None)

# %%
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
df.columns = columns
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Step 2: Explore Basic Statistics
#
# **Tasks:**
#
# 1. Check dataset information using `.info()`.
# 2. Display summary statistics using `.describe()`.
# 3.  Identify missing values using `.isnull().sum()`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
(df == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
cols = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

(df[cols] == 0).sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
df[cols] = df[cols].replace(0, np.nan)

# %%
df[cols] = df[cols].fillna(df[cols].median())

# %%
(df[cols] == 0).sum()
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64

# %% [markdown]
# ### Step 3: Data Visualization
#
# Tasks:
#
# 1. Histogram – Understand the distribution of key features.
# 2. Scatter Plot – Identify patterns between variables (e.g., Glucose vs. Age).
# 3. Correlation Heatmap – Analyze relationships between features.
#
#
#
# ### Histogram of Glucose Levels

# %%
plt.figure(figsize = (6,4))
plt.hist(df["Glucose"], bins = 20)
plt.xlabel("Glucose")
plt.ylabel("Frequency")
plt.title("Histogram of Frquency of Glucose")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.hist(df["Outcome"], bins = 20)
plt.xlabel("Outcome")
plt.ylabel("Frequency")
plt.title("Histogram of Frquency of Outcome")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.hist(df["Insulin"], bins = 25)
plt.xlabel("Insulin")
plt.ylabel("Frequency")
plt.title("Histogram of Frquency of Insulin")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.hist(df["BMI"], bins = 25)
plt.xlabel("BMI")
plt.ylabel("Frequency")
plt.title("Histogram of Frquency of BMI")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.hist(df["BloodPressure"], bins = 25)
plt.xlabel("BloodPressure")
plt.ylabel("Frequency")
plt.title("Histogram of Frquency of BloodPressure")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.hist(df["SkinThickness"], bins = 25)
plt.xlabel("SkinThickness")
plt.ylabel("Frequency")
plt.title("Histogram of Frquency of SkinThickness")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.hist(df["Age"], bins = 25)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Frquency of Age")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.hist(df["DiabetesPedigreeFunction"], bins = 25)
plt.xlabel("DiabetesPedigreeFunction")
plt.ylabel("Frequency")
plt.title("Histogram of Frquency of DiabetesPedigreeFunction")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Scatter Plot: Age vs. Glucose Level

# %%
plt.figure(figsize = (6,4))
plt.scatter(df["Glucose"], df["Age"])
plt.xlabel("Glucose")
plt.ylabel("Age")
plt.title("Scatter Plot for Glucose and Age")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.scatter(df["Outcome"], df["BloodPressure"])
plt.xlabel("Outcome")
plt.ylabel("BloodPressure")
plt.title("Scatter Plot for Outcome and BloodPressure")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.scatter(df["SkinThickness"], df["Insulin"])
plt.xlabel("SkinThickness")
plt.ylabel("Insulin")
plt.title("Scatter Plot for SkinThickness and Insulin")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.scatter(df["Glucose"], df["Insulin"])
plt.xlabel("Glucose")
plt.ylabel("Insulin")
plt.title("Scatter Plot for Glucose and Insulin")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.scatter(df["Pregnancies"], df["Insulin"])
plt.xlabel("Pregnancies")
plt.ylabel("Insulin")
plt.title("Scatter Plot for Pregnancies and Insulin")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.scatter(df["DiabetesPedigreeFunction"], df["Insulin"])
plt.xlabel("DiabetesPedigreeFunction")
plt.ylabel("Insulin")
plt.title("Scatter Plot for DiabetesPedigreeFunction and Insulin")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (6,4))
plt.scatter(df["DiabetesPedigreeFunction"], df["Glucose"])
plt.xlabel("DiabetesPedigreeFunction")
plt.ylabel("Glucose")
plt.title("Scatter Plot for DiabetesPedigreeFunction and Glucose")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Correlation Heatmap

# %%
corr = df.corr(numeric_only = True)

plt.figure(figsize = (8, 6))
plt.imshow(corr, vmin = -1, vmax = 1)
plt.colorbar(label = "Correlation")

plt.xticks(range(len(corr.columns)), corr.columns, rotation = 45, ha = "right")
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 4: Summary and Insights
#
# Tasks:
#
# 1. Write a short summary (2-3 sentences) about your insights below here.
# 2. Answer: What features seem most important for diabetes?

# %% [markdown]
# #### Write your answers to the fourth step in below (double click this markdown cell and after you are finished writing, run the cell (e.g. Ctrl-Enter):
#
#
# 1. Summary:
#
# I got a couple of insights from exploring different histplots and different scatterplots. First for from the histplots, I understood the frequency of each of the variables, such as how many people in their low 20s are included in the dataset, or that most likelt all participants were women looking at the pregnancy data. On average the dataset is consisted of high BMI participants, most also have low skin thickness and people with no diabetes are more regular in the dataset than the ones with.
#
# 2. What features seem most important for diabetes?
#
# Most importnant features looking at the graphs and also mainly the correlation heatmap, is Glucose, BMI, RiskFactir, and a bit lower but still worth exploring more: Insulin, SkinThickness, BMI. Age is relatively towards the younger side so a bit unsure about that.

# %% [markdown]
# ### Conclusion
#
# This classwork provides an Exploratory Data Analysis (EDA) process.
# By analyzing Glucose, BMI, and other features, we can gain insights into risk factors for diabetes.
#
# **Note:** Exploratory Data Analysis (EDA) is the process of analyzing, summarizing, and visualizing data to understand its structure, detect patterns, and find insights before building predictive models.

# %% [markdown]
# ### Deliverables (= what to submit to Itslearning)
#
# Your complete Jupyter Notebook, including all analysis and results exported in **HTML or PDF format**.

# %% [markdown]
# ### Optional Challenge (If You Finish Early)
#
# - Create a boxplot of BMI by diabetes status (`Outcome`).
# - Interpret the relationship between Age and Diabetes using another visualization.

# %%
plt.figure(figsize = (6,4))
df.boxplot(column = "BMI", by = "Outcome")
plt.xlabel("Diabetes Outcome ( 0 is NO and 1 is YES)")
plt.ylabel("BMI")
plt.title("BMI Distribution by Diabetes Status (Outcome)")
plt.suptitle("")
plt.show()

# %%
# Not the best one but I got some small insight

plt.figure(figsize = (6,4))
plt.scatter(df["Age"], df["Glucose"], c = df["Outcome"])
plt.xlabel("Age")
plt.ylabel("Glucose")
plt.title("Age vs Glucose by Diabetes Outcome")
plt.colorbar(label="Outcome, Yellow is Yes, Purple is No")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Interpretation:
#
# Write your interprations here:

# %% [markdown]
# From the BMI and Outcome boxplot, we can see that participants that do not have diabetes, BMI is lower than participants with Diabetes by a significant amount.
#
# From scatterplot, we see that for Diabetic participants, they have higher glucose in the blood on average, and non diabetic have lower glucose in the blood. Makes sense as diabetic participants do not produce enough insulin to lower the blood glucose, and we see that clearly from the graph.
